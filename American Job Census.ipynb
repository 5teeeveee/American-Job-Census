# %% [markdown]
# Instructions:Place csv in same folder as jupyter notebook and run code.
#
# Credits: Csv file provided by Dataquest. Code written as part of Dataquest guided project.

# %% [markdown]
# # Import Data and Remove NA Values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

#Remove NA values
recent_grads = pd.read_csv('recent-grads.csv')
print ('Original number of rows:', recent_grads.shape[0])
recent_grads2 = recent_grads.dropna(axis=0, how ='any')
print('New number of rows:', recent_grads2.shape[0])

#Create column of %men in school
recent_grads2.loc[:,'ShareMen']= recent_grads2.loc[:,'Men'].divide(recent_grads2.loc[:,'Total'])
# Out:
# Original number of rows: 173
# New number of rows: 172
# C:\Users\Steve\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Quick Overview

# %%
print (recent_grads2[recent_grads2['ShareWomen']<0.5]['Unemployment_rate'])
# Out:
# 0      0.018381
# 1      0.117241
# 2      0.024096
# 3      0.050125
# 4      0.061098
# 5      0.177226
# 6      0.095652
# 8      0.057342
# 9      0.059174
# 10     0.065409
# 11     0.065162
# 12     0.092084
# 13     0.023043
# 14     0.006334
# 15     0.087143
# 16     0.042876
# 17     0.059824
# 18     0.061931
# 19     0.011690
# 20     0.063173
# 22     0.087557
# 23     0.027789
# 24     0.058240
# 25     0.070610
# 26     0.060023
# 27     0.047859
# 28     0.074393
# 30     0.093589
# 31     0.055030
# 32     0.089375
#          ...
# 63     0.050031
# 64     0.019642
# 65     0.052539
# 66     0.056357
# 69     0.047179
# 71     0.077250
# 72     0.035354
# 73     0.000000
# 75     0.029480
# 76     0.072218
# 78     0.101175
# 79     0.113459
# 81     0.099723
# 84     0.151850
# 85     0.075449
# 89     0.159491
# 94     0.082452
# 102    0.097244
# 105    0.119511
# 106    0.072725
# 107    0.066619
# 110    0.022229
# 111    0.096726
# 112    0.000000
# ...

# %%
recent_grads2.head(5)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#      ...     Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads2.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed    ...     \
# 168    Biology & Life Science    0.637293           47      6259    ...
# 169  Psychology & Social Work    0.817099            7      2125    ...
# 170  Psychology & Social Work    0.799859           13      2101    ...
# 171  Psychology & Social Work    0.798746           21      3777    ...
# 172                 Education    0.877960            2       742    ...
#
#      Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th  \
# ...

# %%
recent_grads2.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %% [markdown]
# # Custom made scatter matrix

# %%
fig = plt.figure(figsize= (8,8))
fig.subplots_adjust(wspace =0, hspace = 0 )
fig.suptitle('College Major Female Enrollment vs Unemployment Rate Scatter Matrix', fontsize = 15)

sub1 = fig.add_subplot(221)
sub1.hist(recent_grads2['ShareWomen'], range = (recent_grads2['ShareWomen'].min(), recent_grads2['ShareWomen'].max()))
xaxis = sub1.get_xaxis()
yaxis = sub1.get_yaxis()
xaxis.set_visible(False)
sub1.set_ylim(0,30)
sub1.set_ylabel('ShareWomen')
sub1.set_yticklabels([0, 5, 10, 15, 20, 25, 30]) 

sub2 = fig.add_subplot(222)
sub2.scatter(recent_grads2['Unemployment_rate'],recent_grads2['ShareWomen'])
xaxis = sub2.get_xaxis()
yaxis = sub2.get_yaxis()
yaxis.set_visible(False)
xaxis .set_visible(False)
sub2.set_ylim(0,1)
sub2.set_yticklabels([0.00, 0.05, 0.10, 0.15]) 

sub3 = fig.add_subplot(223)
sub3.scatter(recent_grads2['ShareWomen'], recent_grads2['Unemployment_rate'])
xaxis = sub3.get_xaxis()
yaxis = sub3.get_yaxis()
sub3.set_xlabel('ShareWomen')
sub3.set_ylabel('Unemployment_rate')
sub3.set_xlim(0,1)
sub3.set_ylim(0,0.2)
sub3.set_xticklabels([0.0, 0.2, 0.4, 0.6, 0.8], rotation=90) 

sub4 = fig.add_subplot(224)
sub4.hist(recent_grads2['Unemployment_rate'], range = (recent_grads2['Unemployment_rate'].min(), recent_grads2['Unemployment_rate'].max()))
xaxis = sub4.get_xaxis()
yaxis = sub4.get_yaxis()
yaxis.set_visible(False)
sub4.set_xlabel('Unemployment_rate')
sub4.set_xlim(0,0.2)
sub4.set_xticklabels([0.00, 0.05, 0.10, 0.15, 0.20], rotation=90)

# %% [markdown]
# Initial Analysis: No clear correlation between women percentage and unemployment rate.

# %%
arts_df = recent_grads2[recent_grads2['Major_category']=='Arts']
locs = numpy.arange(arts_df.shape[0])

fig2 = plt.figure(figsize=(8,8))
fig2.suptitle('Gender Ratio of Arts Majors', fontsize = 15)
sub1 = fig2.add_subplot(111)
sub1.bar(left = locs, height = arts_df['ShareMen'], width = 0.35)
sub1.set_xticklabels(arts_df['Major'].tolist(), rotation = 90)

offset_locs = locs + 0.35
bar_2 =sub1.bar(left = offset_locs, height = arts_df['ShareWomen'], width = 0.35, color = 'green')

sub1.set_xticks(offset_locs)
sub1.legend(['ShareMen', 'ShareWomen'], loc = 'upper left')

# %% [markdown]
# Initial Analysis: Women hold a >65% percentage in visual, performing, studio, drama, theater, commercial and graphic design arts. Music is split roughly 1:1 between males and females. The only male majority arts majors are miscellaneous fine arts and film/video/photographics arts.

# %%
fig = plt.figure(figsize= (8,8))
fig.subplots_adjust(wspace =0, hspace = 0 )
fig.suptitle('College Major Male Enrollment vs Unemployment Rate Scatter Matrix', fontsize = 15)

sub1 = fig.add_subplot(221)
plt.hist(recent_grads2['ShareMen'])
xaxis = sub1.get_xaxis()
yaxis = sub1.get_yaxis()
xaxis.set_visible(False)
sub1.set_ylim(0,30)
sub1.set_ylabel('ShareMen')
sub1.set_yticklabels([0, 5, 10, 15, 20, 25, 30]) 

sub2 = fig.add_subplot(222)
plt.scatter(recent_grads2['Unemployment_rate'], recent_grads2['ShareMen'])
xaxis = sub2.get_xaxis()
yaxis = sub2.get_yaxis()
yaxis.set_visible(False)
xaxis .set_visible(False)
sub2.set_ylim(0,1)
sub2.set_yticklabels([0.00, 0.05, 0.10, 0.15]) 

sub3 = fig.add_subplot(223)
plt.scatter(recent_grads2['ShareMen'],recent_grads2['Unemployment_rate'])
xaxis = sub3.get_xaxis()
yaxis = sub3.get_yaxis()
sub3.set_xlabel('ShareMen')
sub3.set_ylabel('Unemployment_rate')
sub3.set_xlim(0,1)
sub3.set_ylim(0,0.2)
sub3.set_xticklabels([0.0, 0.2, 0.4, 0.6, 0.8], rotation=90) 

sub4 = fig.add_subplot(224)
plt.hist(recent_grads2['Unemployment_rate'])
xaxis = sub4.get_xaxis()
yaxis = sub4.get_yaxis()
yaxis.set_visible(False)
sub4.set_xlabel('Unemployment_rate')
sub4.set_xlim(0,0.2)
sub4.set_xticklabels([0.00, 0.05, 0.10, 0.15, 0.20], rotation=90)

# %% [markdown]
# Initial Analysis: No clear correlation between male enrollment and unemployment rate of college majors.

# %% [markdown]
# Future work: Look into gender ratio of other areas (Science, Technology, Engineering, Management). Rank majors according to unemployment rate.
